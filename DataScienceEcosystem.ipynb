# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.

# %% [markdown]
# <p style="font-size:24px;">In this notebook, Data Science Tools and Ecosystem are summarized.</p>

# %% [markdown]
# <p style="font-size:24px;">Some of the popular languages that Data Scientists use are:</p>
# <ul style="font-size:12px;">
#     <li>Python</li>
#     <li>R</li>
#     <li>SQL</li>
#     <li>Julia</li>
#     <li>Scala</li>
# </ul>

# %% [markdown]
# <h2>Some of the commonly used libraries used by Data Scientists include:</h2>
# <table style="font-size:12px; border-collapse: collapse; width: 50%;">
#     <tr>
#         <th style="border: 4px solid black; text-align: left;">Tools Below:</th>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black;">1-JupyterLab</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black;">2-RStudio</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black;">3-VS Code</td>
#     </tr>
# </table>

# %% [markdown]
# ### - Below are a few examples of evaluating arithmetic expressions in Python.-
#
# - **Addition:** `3 + 5` = 8
# - **Subtraction:** `10 - 4` = 6
# - **Multiplication:** `7 * 6` = 42
# - **Division:** `16 / 4` = 4
# - **Exponentiation:** `2 ** 3` = 8
# - **Modulo:** `10 % 3` = 1

# %%
# This is a simple arithmetic expression to multiply then add integers
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# **OBJECTIVES:**
#
# - List popular languages for Data Science:
#   - Python
#   - R
#   - SQL
#   - Julia
#   - Scala
# - Identify open-source tools used in Data Science.
# - Demonstrate examples of basic arithmetic expressions in Python.
# - Convert minutes to hours using Python.
# - Understand the structure and purpose of Jupyter Notebooks.

# %% [markdown]
# ## Author
#
# Osman
